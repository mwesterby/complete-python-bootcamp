# %% [markdown]
# You define tuples with `()`

# %%
t = (1, 2, 3)

# %%
myList = [1, 2, 3]

# %%
type(t)
# Out:
# tuple

# %%
type(myList)
# Out:
# list

# %%
len(t)
# Out:
# 3

# %% [markdown]
# Tuples can have mixes types

# %%
t = ('one', 2)

# %%
t[0]
# Out:
# 'one'

# %%
t[-1]
# Out:
# 2

# %%
t = ('a', 'a', 'b')

# %% [markdown]
# `.count()` returns how many times that element appears in the tuple

# %%
t.count('a')
# Out:
# 2

# %% [markdown]
# `.index()` returns the first index the element supplied occurs in the tuple

# %%
t.index('a')
# Out:
# 0

# %%
t.index('b')
# Out:
# 2

# %%
t
# Out:
# ('a', 'a', 'b')

# %%
myList
# Out:
# [1, 2, 3]

# %%
myList[0] = 'new'

# %%
myList
# Out:
# ['new', 2, 3]

# %% [markdown]
# Tuples are immutable

# %%
t[0] = 'new'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f469ab99125e> in <module>
# ----> 1 t[0] = 'new'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Convenient for data integrity
